# %% [markdown]
# <h1>Get melspectrogram</h1>

# %%
import IPython.display as ipd
from matplotlib import pyplot as plt
from editor_function.dataset_editor import DatasetEditor

# %matplotlib notebook

# %%
dataset_path = "dataset_path"

dataset_editor = DatasetEditor(ipd, plt)
dataset_editor.load_dataset(dataset_path)

# %%
index = 0
dataset_editor.set_index(index)
dataset_editor.refresh_display(True)
# Out:
# 音檔編號：0, 原檔名稱：音檔/0000.mp3
# <img src="data:image/png;base64,..." width="640">
# ...
